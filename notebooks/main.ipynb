# %% [markdown]
# Импорт библиотек и модулей

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import torch
import pandas as pd
import numpy as np
from src.data_loader import load_data, create_dataloaders
from src.preprocess import preprocess_data
from src.model import MLP1, MLP2
from src.train import train_model
from src.utils import rmse, mae, load_model
from src.visualize import plot_loss, plot_predictions

# %% [markdown]
# Загрузка данных

# %%
train_df, test_df = load_data('../data/train.csv', '../data/test.csv')

# %% [markdown]
# Предобработка

# %%
X_train, y_train, X_test = preprocess_data(train_df, test_df)
train_loader, val_loader = create_dataloaders(X_train, y_train, batch_size=32)
# Out:
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna(all_df[c].median(), inplace=True)
# c:\Users\ADM\ml_project\src\preprocess.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_df[c].fillna('Missing', inplace=True)

# %% [markdown]
# Определение моделей и сравнение

# %%
models = {'MLP1': MLP1(X_train.shape[1]), 'MLP2': MLP2(X_train.shape[1])}
histories = {}

for name, model in models.items():
    print(f"Training {name}")
    trained_model, train_losses, val_losses = train_model(model, train_loader, val_loader, num_epochs=30, lr=1e-3)
    histories[name] = {
        'train_losses': train_losses,
        'val_losses': val_losses
    }
# Out:
# Training MLP1
# Epoch 01: train_loss=39357313854.2703, val_loss=37415028121.6000, val_rmse=193429.6562
# Model saved to outputs/models/best_model.pt
# Epoch 02: train_loss=39372978176.0000, val_loss=37408984268.8000, val_rmse=193414.0312
# Model saved to outputs/models/best_model.pt
# Epoch 03: train_loss=39393168965.1892, val_loss=37398251110.4000, val_rmse=193386.2812
# Model saved to outputs/models/best_model.pt
# Epoch 04: train_loss=39770850608.4324, val_loss=37382348595.2000, val_rmse=193345.1562
# Model saved to outputs/models/best_model.pt
# Epoch 05: train_loss=39458782678.4865, val_loss=37360738713.6000, val_rmse=193289.2656
# Model saved to outputs/models/best_model.pt
# Epoch 06: train_loss=39255891082.3784, val_loss=37333857280.0000, val_rmse=193219.7031
# Model saved to outputs/models/best_model.pt
# Epoch 07: train_loss=39229015178.3784, val_loss=37301846835.2000, val_rmse=193136.8594
# Model saved to outputs/models/best_model.pt
# Epoch 08: train_loss=39443122563.4595, val_loss=37264205414.4000, val_rmse=193039.3906
# Model saved to outputs/models/best_model.pt
# Epoch 09: train_loss=39253768911.5676, val_loss=37221509120.0000, val_rmse=192928.7656
# Model saved to outputs/models/best_model.pt
# Epoch 10: train_loss=39064709784.2162, val_loss=37173639987.2000, val_rmse=192804.6719
# Model saved to outputs/models/best_model.pt
# Epoch 11: train_loss=39015016226.5946, val_loss=37121172070.4000, val_rmse=192668.5469
# Model saved to outputs/models/best_model.pt
# Epoch 12: train_loss=39024002961.2973, val_loss=37064038195.2000, val_rmse=192520.2344
# Model saved to outputs/models/best_model.pt
# Epoch 13: train_loss=39144615659.2432, val_loss=37001565184.0000, val_rmse=192357.9219
# Model saved to outputs/models/best_model.pt
# Epoch 14: train_loss=39260679527.7838, val_loss=36934576742.4000, val_rmse=192183.7031
# Model saved to outputs/models/best_model.pt
# Epoch 15: train_loss=38733486135.3513, val_loss=36862976409.6000, val_rmse=191997.3281
# Model saved to outputs/models/best_model.pt
# Epoch 16: train_loss=38752603772.5405, val_loss=36787294412.8000, val_rmse=191800.1406
# Model saved to outputs/models/best_model.pt
# Epoch 17: train_loss=38785295166.2703, val_loss=36706545459.2000, val_rmse=191589.5156
# Model saved to outputs/models/best_model.pt
# Epoch 18: train_loss=38676790521.0811, val_loss=36621684940.8000, val_rmse=191367.9375
# Model saved to outputs/models/best_model.pt
# Epoch 19: train_loss=38503093109.6216, val_loss=36532415897.6000, val_rmse=191134.5469
# Model saved to outputs/models/best_model.pt
# Epoch 20: train_loss=38854253429.6216, val_loss=36438530048.0000, val_rmse=190888.7969
# Model saved to outputs/models/best_model.pt
# Epoch 21: train_loss=38317202127.5676, val_loss=36342388531.2000, val_rmse=190636.7969
# Model saved to outputs/models/best_model.pt
# Epoch 22: train_loss=38165496306.1622, val_loss=36240838860.8000, val_rmse=190370.2656
# Model saved to outputs/models/best_model.pt
# Epoch 23: train_loss=38389523871.1351, val_loss=36135416217.6000, val_rmse=190093.1719
# Model saved to outputs/models/best_model.pt
# Epoch 24: train_loss=37968365401.9459, val_loss=36025788825.6000, val_rmse=189804.6094
# Model saved to outputs/models/best_model.pt
# Epoch 25: train_loss=37827751769.9459, val_loss=35913349734.4000, val_rmse=189508.1875
# Model saved to outputs/models/best_model.pt
# Epoch 26: train_loss=37984126145.7297, val_loss=35797241651.2000, val_rmse=189201.5938
# Model saved to outputs/models/best_model.pt
# Epoch 27: train_loss=37578516424.6487, val_loss=35676493824.0000, val_rmse=188882.2188
# Model saved to outputs/models/best_model.pt
# Epoch 28: train_loss=37567963855.5676, val_loss=35553205452.8000, val_rmse=188555.5781
# Model saved to outputs/models/best_model.pt
# Epoch 29: train_loss=37392241193.5135, val_loss=35426585600.0000, val_rmse=188219.5156
# Model saved to outputs/models/best_model.pt
# Epoch 30: train_loss=37509000883.8919, val_loss=35295563980.8000, val_rmse=187871.1406
# Model saved to outputs/models/best_model.pt
# Training MLP2
# Epoch 01: train_loss=39403961150.2703, val_loss=37406744576.0000, val_rmse=193408.2344
# Model saved to outputs/models/best_model.pt
# Epoch 02: train_loss=39473103401.5135, val_loss=37314037145.6000, val_rmse=193168.4219
# Model saved to outputs/models/best_model.pt
# Epoch 03: train_loss=39056596217.0811, val_loss=36973309542.4000, val_rmse=192284.4375
# Model saved to outputs/models/best_model.pt
# Epoch 04: train_loss=38918445775.5676, val_loss=36170784768.0000, val_rmse=190186.1875
# Model saved to outputs/models/best_model.pt
# Epoch 05: train_loss=37519283504.4324, val_loss=34690811084.8000, val_rmse=186254.7031
# Model saved to outputs/models/best_model.pt
# Epoch 06: train_loss=35787971943.7838, val_loss=32403382067.2000, val_rmse=180009.4062
# Model saved to outputs/models/best_model.pt
# Epoch 07: train_loss=32955214598.9189, val_loss=29254909337.6000, val_rmse=171040.6719
# Model saved to outputs/models/best_model.pt
# Epoch 08: train_loss=29289382220.1081, val_loss=25351340851.2000, val_rmse=159221.0469
# Model saved to outputs/models/best_model.pt
# Epoch 09: train_loss=25069006571.2432, val_loss=20934294528.0000, val_rmse=144686.8906
# Model saved to outputs/models/best_model.pt
# Epoch 10: train_loss=20260843381.6216, val_loss=16242109952.0000, val_rmse=127444.5312
# Model saved to outputs/models/best_model.pt
# Epoch 11: train_loss=15434601900.9730, val_loss=11874541363.2000, val_rmse=108970.3672
# Model saved to outputs/models/best_model.pt
# Epoch 12: train_loss=11260262676.7568, val_loss=8206367948.8000, val_rmse=90589.0078
# Model saved to outputs/models/best_model.pt
# Epoch 13: train_loss=7839620718.7027, val_loss=5434709760.0000, val_rmse=73720.4844
# Model saved to outputs/models/best_model.pt
# Epoch 14: train_loss=5524876810.3784, val_loss=3614871936.0000, val_rmse=60123.8047
# Model saved to outputs/models/best_model.pt
# Epoch 15: train_loss=3938784840.6486, val_loss=2611920204.8000, val_rmse=51106.9453
# Model saved to outputs/models/best_model.pt
# Epoch 16: train_loss=3074543602.1622, val_loss=2092744329.6000, val_rmse=45746.5234
# Model saved to outputs/models/best_model.pt
# Epoch 17: train_loss=2575332049.2973, val_loss=1849719756.8000, val_rmse=43008.3672
# Model saved to outputs/models/best_model.pt
# Epoch 18: train_loss=2378350000.4324, val_loss=1711829552.0000, val_rmse=41374.2617
# Model saved to outputs/models/best_model.pt
# Epoch 19: train_loss=2240069899.2432, val_loss=1615809600.0000, val_rmse=40197.1328
# Model saved to outputs/models/best_model.pt
# Epoch 20: train_loss=2183790661.1892, val_loss=1541323574.4000, val_rmse=39259.6914
# Model saved to outputs/models/best_model.pt
# Epoch 21: train_loss=2010198515.0270, val_loss=1473056515.2000, val_rmse=38380.4180
# Model saved to outputs/models/best_model.pt
# Epoch 22: train_loss=2034974318.7027, val_loss=1417577190.4000, val_rmse=37650.7266
# Model saved to outputs/models/best_model.pt
# Epoch 23: train_loss=1858214240.8649, val_loss=1365898848.0000, val_rmse=36958.0703
# Model saved to outputs/models/best_model.pt
# Epoch 24: train_loss=1834041096.6486, val_loss=1320822486.4000, val_rmse=36343.1211
# Model saved to outputs/models/best_model.pt
# Epoch 25: train_loss=1908362292.7568, val_loss=1283556764.8000, val_rmse=35826.7617
# Model saved to outputs/models/best_model.pt
# Epoch 26: train_loss=1818146836.7568, val_loss=1246514118.4000, val_rmse=35306.0039
# Model saved to outputs/models/best_model.pt
# Epoch 27: train_loss=1734248589.8378, val_loss=1217054364.8000, val_rmse=34886.3047
# Model saved to outputs/models/best_model.pt
# Epoch 28: train_loss=1705153680.4324, val_loss=1188348307.2000, val_rmse=34472.4297
# Model saved to outputs/models/best_model.pt
# Epoch 29: train_loss=1651747859.8919, val_loss=1166321929.6000, val_rmse=34151.4570
# Model saved to outputs/models/best_model.pt
# Epoch 30: train_loss=1637616342.4865, val_loss=1146510048.0000, val_rmse=33860.1562
# Model saved to outputs/models/best_model.pt

# %% [markdown]
# Загрузка лучшей модели и предсказания

# %%
best_model = MLP2(X_train.shape[1])
# Текущая директория - notebooks
best_model = load_model(best_model, 'outputs/models/best_model.pt')
y_pred = best_model(torch.tensor(X_test, dtype=torch.float32))
# Out:
# C:\Users\ADM\AppData\Local\Temp\ipykernel_30216\4114953146.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = best_model(torch.tensor(X_test, dtype=torch.float32))

# %% [markdown]
# Визуализация результатов

# %%
import os

# Текущая директория - notebooks
current_dir = os.getcwd()

# Поднимаемся на уровень выше (корень проекта)
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Путь к папке outputs/figures
save_path = os.path.join(project_root, 'outputs', 'figures', 'loss.png')

plot_loss(
    histories['MLP2']['train_losses'],
    histories['MLP2']['val_losses'],
    save_path
)

# %% [markdown]
# Вычислим предсказания на валидационном наборе

# %%
y_true_list, y_pred_list = [], []
for x_batch, y_batch in val_loader:
    preds = best_model(x_batch)
    y_true_list.append(y_batch.numpy())
    y_pred_list.append(preds.detach().numpy())

y_true = np.concatenate(y_true_list).flatten()
y_pred = np.concatenate(y_pred_list).flatten()

# %% [markdown]
# Сохраним сравнение реальных и предсказанных цен

# %%
# Текущая директория - notebooks
current_dir = os.getcwd()

# Поднимаемся на уровень выше (корень проекта)
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Путь к папке outputs/figures
save_path = os.path.join(project_root, 'outputs', 'figures', 'predictions.png')

plot_predictions(
    y_true,
    y_pred,
    save_path
)

# %% [markdown]
# Сохранение предсказаний

# %%
# Текущая директория - notebooks
current_dir = os.getcwd()

# Поднимаемся на уровень выше (корень проекта)
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Путь к папке outputs/figures
save_path = os.path.join(project_root, 'outputs', 'figures', 'submission.csv')
print(len(test_df['Id']), y_pred.shape[0])
print(f"Размер test_df: {len(test_df)}")
submission = pd.DataFrame({'Id': test_df['Id'][:292], 'SalePrice': y_pred[:292]})
submission.to_csv(save_path, index=False)
# Out:
# 1459 292
# Размер test_df: 1459
